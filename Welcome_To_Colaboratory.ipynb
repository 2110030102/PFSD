# %% [markdown]
# <a href="https://colab.research.google.com/github/2110030102/PFSD/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n1=6
n2=3
res=n1+n2
print('Add=',res)
res=n1-n2
print('sub=',res)
res=n1*n2
print('Mul=',res)
res=n1/n2
print('Div=',res)
# Out:
# Add= 9
# sub= 3
# Mul= 18
# Div= 2.0
